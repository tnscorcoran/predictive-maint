# %% [markdown]
# # 1. **Develop solution:**  Scene Change Detection

# %% [markdown]
# ## 1.1. Introduction

# %% [raw]
# In this part of the series, we will train an Machine learning or Deep learning based model (implemented in Keras) in for Anomaly Detection in Survaliance cameras. The trained model will be evaluated on pre-labeled and anonymized dataset.
#
# Ready? Let's go!

# %% [markdown]
# ## 1.2.  Install the modeling requirements and libraries

# %% [markdown]
# First, we'll need to **install some libraries** that are not part of our container image. Normally, **Red Hat OpenShift Data Science** or **Red Hat Open Data Hub** is already taking care of this for you, based on what it detects in the code. **Red Hat OpenShift Data Science** or **Red Hat Open Data Hub** will reinstall all those libraries for you every time you launch the notebook!
#
# In case you're using this notebook in a different environment, or just to make sure everything is ready, you can run the following cell to install  Keras (an abstraction layer over Tensorflow).

# %% [markdown]
# ## 1.3.  Importing the needed libraries and packages
# Of course, we'll need to import various packages. They are either built in the notebook image you are running, or have been installed in the previous step.

# %%
import os, sys; sys.path.append(os.path.dirname(os.getcwd()))

# %%
os.chdir('/opt/app-root/src/predictive-maint/')
os.environ["REPO_PATH"]="/opt/app-root/src/predictive-maint/"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import requests
from training.src.dataloading.read_dataset import readData
from training.src.features.data_preprocessing import preprocessData
from training.src.visualization.visualize import visualizeData
from training.src.modules.build_model import buildModel
from training.src.modules.train_model import  trainModel,MLflow
from training.src.modules.predict_model import predictor
from training.src.hyper_parameters.hps import get_hyper_paras
# from training.src.github_commands.git_utils import gitCommands
from training.src.deploy_app.deploy import deployApplication



import os, sys; sys.path.append(os.path.dirname(os.getcwd()))

import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow import keras
from tensorflow.keras import layers
import mlflow
import warnings
import numpy as np
from minio import Minio
import zipfile

# %% [markdown]
# ## 1.4. Initialize some hyper-parameters

# %%
SPLITE_RATE, OUTPUT_FEATURE_NAME, BATCH_SIZE, IMAGE_SIZE, INPUT_SHAPE, DROP_OUT_RATE, EPOCHS, SEED, TRAIN_DATA_FLAG, FINE_TUNE_FLAG = get_hyper_paras()
SPLITE_RATE, OUTPUT_FEATURE_NAME, BATCH_SIZE, IMAGE_SIZE, INPUT_SHAPE, DROP_OUT_RATE, EPOCHS, SEED, TRAIN_DATA_FLAG, FINE_TUNE_FLAG
# Out:
# /opt/app-root/src----predictive-maint
# (0.2,
#  ['Background', 'Person', 'Finger'],
#  32,
#  (256, 256),
#  (256, 256, 3),
#  0.2,
#  3,
#  100,
#  True,
#  False)

# %% [markdown]
# ### 1.4.1. Define a client to read from Minio S3 Bucket

# %%
def get_s3_server():
    minioClient = Minio(os.environ['MLFLOW_S3_ENDPOINT'],
                    access_key=os.environ['AWS_ACCESS_KEY_ID'],
                    secret_key=os.environ['AWS_SECRET_ACCESS_KEY'],
                    secure=False)

    return minioClient
client = get_s3_server()

# %% [markdown]
# ### 1.4.2. SetUp MLFlow to track the model

# %%
mlflow = MLflow(mlflow).SetUp_Mlflow()

# %% [markdown]
# ## 1.5. Reading the  Dataset

# %%
train_ds, val_ds, test_ds, num_classes = readData(dataPath = os.environ['DATA_PATH'],imageSize = IMAGE_SIZE, batchSize = BATCH_SIZE, seed = SEED  ).generateData()
# Out:
# Found 32 files belonging to 3 classes.
# Using 26 files for training.
# Found 32 files belonging to 3 classes.
# Using 6 files for validation.
# Found 32 files belonging to 3 classes.
# Using 6 files for validation.

# %% [markdown]
# ## 1.6.  Data Preprocessing

# %% [markdown]
# We need to resize the data to make them ready for feeing to our model

# %%
train_ds, val_ds, test_ds, data_augmentation  = preprocessData(trainDs = train_ds,testDs = test_ds,valDs = val_ds,numClasses = num_classes,augFlag=True,height=IMAGE_SIZE[0],width=IMAGE_SIZE[1],batchSize = BATCH_SIZE).dataPreProcessing()

# %%
train_ds
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float32, name=None))>

# %%
val_ds
# Out:
# <MapDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float32, name=None))>

# %% [markdown]
# ## 1.7.  Design and compile the model

# %%
clf = buildModel(dataAugmentation = data_augmentation, inputShape=INPUT_SHAPE, numClasses=num_classes, topDropoutRate=DROP_OUT_RATE).setupModel()
# clf.summary()

# %% [markdown]
# ## 1.8.  Training the Model

# %%
clf = trainModel(model = clf, trainDs = train_ds, valDs = val_ds, batchSize=32, epochs=5, mlflow=mlflow).ModelTraining()
# Out:
# Epoch 1/5
# 1/1 [==============================] - 16s 16s/step - loss: 1.5032 - accuracy: 0.3077 - val_loss: 0.9641 - val_accuracy: 0.3333
# Epoch 2/5
# 1/1 [==============================] - 7s 7s/step - loss: 0.1189 - accuracy: 0.9615 - val_loss: 0.7408 - val_accuracy: 0.3333
# Epoch 3/5
# 1/1 [==============================] - 7s 7s/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.6233 - val_accuracy: 0.8333
# Epoch 4/5
# 1/1 [==============================] - 7s 7s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5565 - val_accuracy: 0.8333
# Epoch 5/5
# 1/1 [==============================] - 7s 7s/step - loss: 9.8990e-04 - accuracy: 1.0000 - val_loss: 0.5158 - val_accuracy: 0.8333
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 81). These functions will not be directly callable after loading.

# %%
train_ds
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float32, name=None))>

# %% [markdown]
# # 3. **Deploy solution as an app with model serving tool Seldon**

# %%
os.environ['OPENSHIFT_CLIENT_PYTHON_DEFAULT_OC_PATH'] = '/opt/app-root/bin/oc'

deployApplication().deployApp()
# Out:
# /opt/app-root/src
# /opt/app-root/src/predictive-maint//training/deploy/
# Collecting openshift-client
#   Downloading openshift_client-1.0.17-py2.py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 KB 25.8 MB/s eta 0:00:00
# Requirement already satisfied: six in /opt/app-root/lib/python3.8/site-packages (from openshift-client) (1.15.0)
# Requirement already satisfied: pyyaml in /opt/app-root/lib/python3.8/site-packages (from openshift-client) (5.4.1)
# Collecting paramiko
#   Downloading paramiko-2.11.0-py2.py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 KB 193.1 MB/s eta 0:00:00
# Requirement already satisfied: pynacl>=1.0.1 in /opt/app-root/lib/python3.8/site-packages (from paramiko->openshift-client) (1.4.0)
# Requirement already satisfied: cryptography>=2.5 in /opt/app-root/lib/python3.8/site-packages (from paramiko->openshift-client) (3.4.8)
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-4.0.0-cp36-abi3-manylinux_2_28_x86_64.whl (594 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.4/594.4 KB 319.7 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.12 in /opt/app-root/lib/python3.8/site-packages (from cryptography>=2.5->paramiko->openshift-client) (1.14.6)
# Requirement already satisfied: pycparser in /opt/app-root/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=2.5->paramiko->openshift-client) (2.20)
# Installing collected packages: bcrypt, paramiko, openshift-client
# Successfully installed bcrypt-4.0.0 openshift-client-1.0.17 paramiko-2.11.0
# /opt/app-root/src/predictive-maint/training/deploy
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Start OCP things...
# OpenShift client version: 3.11.153
# ml-workshop
# 0
# Starting Build and Waiting. This can take several minutes.....
# Build Finished
# 0
# Build Log: ml-workshop:buildconfig.build.openshift.io/seldon-model-pred-demo-opentlc-mgr-v1
# Receiving source from STDIN as archive ...
# Replaced Dockerfile FROM image quay.io/ml-aml-workshop/python:3.7-slimv2
# time="2022-09-12T03:40:59Z" level=info msg="Not using native diff for overlay, this may cause degraded performance for building images: kernel has CONFIG_OVERLAY_FS_REDIRECT_DIR enabled"
# I0912 03:40:59.340644       1 defaults.go:102] Defaulting to storage driver "overlay" with options [mountopt=metacopy=on].
# Caching blobs under "/var/cache/blobs".
#
# Pulling image registry.access.redhat.com/ubi8/python-38@sha256:43b037584dac3425f845faab4f3575a9058c431219ffbf735f937b263713f2d9 ...
# Trying to pull registry.access.redhat.com/ubi8/python-38@sha256:43b037584dac3425f845faab4f3575a9058c431219ffbf735f937b263713f2d9...
# Getting image source signatures
# Copying blob sha256:44115d860fcecaa250b811cc4120d7ba18a2250bada1fe15199de53cefde7fc7
# Copying blob sha256:c101ad5bb4fe96ea9b773498ec3f14371a0da1110add338f003c8c9cdbf15d07
# Copying blob sha256:be84118e6017ca944a551a0f22d93ae3600941ea76e13cb01be584ab822cdecf
# Copying blob sha256:06038631a24a25348b51d1bfc7d0a0ee555552a8998f8328f9b657d02dd4c64c
# Copying blob sha256:262268b65bd5f33784d6a61514964887bc18bc00c60c588bc62bfae7edca46f1
# Copying config sha256:f6d9ea021c5484ffa2073378732cc3d456438af84d673753f7b891f977e4f561
# Writing manifest to image destination
# Storing signatures
# Adding transient rw bind mount for /run/secrets/rhsm
# STEP 1/14: FROM registry.access.redhat.com/ubi8/python-38@sha256:43b037584dac3425f845faab4f3575a9058c431219ffbf735f937b263713f2d9
# STEP 2/14: WORKDIR /microservice
# --> 8a39aea7b2a
# STEP 3/14: COPY requirements.txt /microservice/
# --> b82f462ed65
# STEP 4/14: RUN pip install -r requirements.txt
# Collecting tensorflow
#   Downloading https://files.pythonhosted.org/packages/82/59/08ee5d0c194cab88b38fd7b701c66ce33d021dc21fd04b2461176379e535/tensorflow-2.10.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578.1MB)
# Collecting typing-extensions>=3.6.6
#   Downloading https://files.pythonhosted.org/packages/ed/d6/2afc375a8d55b8be879d6b4986d4f69f01115e795e36827fd3a40166028b/typing_extensions-4.3.0-py3-none-any.whl
# Collecting google-pasta>=0.1.1
#   Downloading https://files.pythonhosted.org/packages/a3/de/c648ef6835192e6e2cc03f40b19eeda4382c49b5bafb43d88b931c4c74ac/google_pasta-0.2.0-py3-none-any.whl (57kB)
# Collecting h5py>=2.9.0
#   Downloading https://files.pythonhosted.org/packages/4b/ad/67136179798bef7f49eebac34024f9dc3052f4c4a5d1372fcfd5dd9aca5f/h5py-3.7.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.5MB)
# Collecting flatbuffers>=2.0
#   Downloading https://files.pythonhosted.org/packages/d7/0d/b5bfb553a6ac66d6ec2b6d7f1e814a908fba7188356ac94bb36ae3d905c3/flatbuffers-2.0.7-py2.py3-none-any.whl
# Collecting protobuf<3.20,>=3.9.2
#   Downloading https://files.pythonhosted.org/packages/d5/c8/64de54ef0121a1ff6309f102124c6b5a89260dc584e1871341f5199b7b85/protobuf-3.19.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1MB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading https://files.pythonhosted.org/packages/cf/ef/2b8be753a3454f568faa10c79d607c99374c8f48d2f6788a39ab69dd3ce1/tensorflow_io_gcs_filesystem-0.27.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4MB)
# Collecting keras-preprocessing>=1.1.1
#   Downloading https://files.pythonhosted.org/packages/79/4c/7c3275a01e12ef9368a892926ab932b33bb13d55794881e3573482b378a7/Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42kB)
# Collecting six>=1.12.0
#   Downloading https://files.pythonhosted.org/packages/d9/5a/e7c31adbe875f2abbb91bd84cf2dc52d792b5a01506781dbcf25c91daf11/six-1.16.0-py2.py3-none-any.whl
# Collecting absl-py>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/a5/b8/fc74a554a6fc7f26744c883ebfe405cf49c1f1320f13ee874aee47c70e1d/absl_py-1.2.0-py3-none-any.whl (123kB)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading https://files.pythonhosted.org/packages/b6/48/583c032b79ae5b3daa02225a675aeb673e58d2cb698e78510feceb11958c/gast-0.4.0-py3-none-any.whl
# Collecting opt-einsum>=2.3.2
#   Downloading https://files.pythonhosted.org/packages/bc/19/404708a7e54ad2798907210462fd950c3442ea51acc8790f3da48d2bee8b/opt_einsum-3.3.0-py3-none-any.whl (65kB)
# Collecting termcolor>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/4f/76/6aef5db121bd67ccfa9ce8f7d2703231f58e5a5221e1782f68b6c8f12e5c/termcolor-2.0.0-py3-none-any.whl
# Collecting packaging
#   Downloading https://files.pythonhosted.org/packages/05/8e/8de486cbd03baba4deef4142bd643a3e7bbe954a784dc1bb17142572d127/packaging-21.3-py3-none-any.whl (40kB)
# Collecting astunparse>=1.6.0
#   Downloading https://files.pythonhosted.org/packages/2b/03/13dde6512ad7b4557eb792fbcf0c653af6076b81e5941d36ec61f7ce6028/astunparse-1.6.3-py2.py3-none-any.whl
# Collecting tensorboard<2.11,>=2.10
#   Downloading https://files.pythonhosted.org/packages/6b/42/e271c40c84c250b52fa460fda970899407c837a2049c53969f37e404b1f6/tensorboard-2.10.0-py3-none-any.whl (5.9MB)
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Downloading https://files.pythonhosted.org/packages/b6/05/9d7f3a6c783669cba36a6eb4555d0c73a516eee935dde6176dfb8512f94e/tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438kB)
# Requirement already satisfied: setuptools in /opt/app-root/lib/python3.8/site-packages (from tensorflow->-r requirements.txt (line 1)) (41.6.0)
# Collecting keras<2.11,>=2.10.0
#   Downloading https://files.pythonhosted.org/packages/f9/4d/dc255a437c9616b155e5bd55e325e092b7cdcb4652361d733ae051d40853/keras-2.10.0-py2.py3-none-any.whl (1.7MB)
# Collecting wrapt>=1.11.0
#   Downloading https://files.pythonhosted.org/packages/36/ee/944dc7e5462662270e8a379755bcc543fc8f09029866288060dc163ed5b4/wrapt-1.14.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (81kB)
# Collecting libclang>=13.0.0
#   Downloading https://files.pythonhosted.org/packages/45/ff/2a6a2a536fc9a2893a6abfb8bbe317200db0475a0c474eccc9d47fa09d48/libclang-14.0.6-py2.py3-none-manylinux2010_x86_64.whl (14.1MB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading https://files.pythonhosted.org/packages/74/ab/3db763996ac5f51c6158ca91d3e23f5e41999c90d15672a95dfe1bb6af94/grpcio-1.48.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6MB)
# Collecting numpy>=1.20
#   Downloading https://files.pythonhosted.org/packages/d6/e2/bed33bdbf513cd6d3fcb4377792ef1b8aad941da542a191e1e2a98c6621f/numpy-1.23.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1MB)
# Collecting pyparsing!=3.0.5,>=2.0.2
#   Downloading https://files.pythonhosted.org/packages/6c/10/a7d0fa5baea8fe7b50f448ab742f26f52b80bfca85ac2be9d35cdd9a3246/pyparsing-3.0.9-py3-none-any.whl (98kB)
# Collecting wheel<1.0,>=0.23.0
#   Downloading https://files.pythonhosted.org/packages/27/d6/003e593296a85fd6ed616ed962795b2f87709c3eee2bca4f6d0fe55c6d00/wheel-0.37.1-py2.py3-none-any.whl
# Collecting requests<3,>=2.21.0
#   Downloading https://files.pythonhosted.org/packages/ca/91/6d9b8ccacd0412c08820f72cebaa4f0c0441b5cda699c90f618b6f8a1b42/requests-2.28.1-py3-none-any.whl (62kB)
# Collecting markdown>=2.6.8
#   Downloading https://files.pythonhosted.org/packages/86/be/ad281f7a3686b38dd8a307fa33210cdf2130404dfef668a37a4166d737ca/Markdown-3.4.1-py3-none-any.whl (93kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading https://files.pythonhosted.org/packages/b1/0e/0636cc1448a7abc444fb1b3a63655e294e0d2d49092dc3de05241be6d43c/google_auth_oauthlib-0.4.6-py2.py3-none-any.whl
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading https://files.pythonhosted.org/packages/60/f9/802efd84988bffd9f644c03b6e66fde8e76c3aa33db4279ddd11c5d61f4b/tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9MB)
# Collecting google-auth<3,>=1.6.3
#   Downloading https://files.pythonhosted.org/packages/bb/6c/9b2dab3aff0dd9f685386598434dd8a0f205096b0a68d2c5e0c11be6f4b6/google_auth-2.11.0-py2.py3-none-any.whl (167kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading https://files.pythonhosted.org/packages/e0/68/e8ecfac5dd594b676c23a7f07ea34c197d7d69b3313afdf8ac1b0a9905a2/tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781kB)
# Collecting werkzeug>=1.0.1
#   Downloading https://files.pythonhosted.org/packages/c8/27/be6ddbcf60115305205de79c29004a0c6bc53cec814f733467b1bb89386d/Werkzeug-2.2.2-py3-none-any.whl (232kB)
# Collecting certifi>=2017.4.17
#   Downloading https://files.pythonhosted.org/packages/ac/80/e0df41f336f21d35befa4ff15348eb3e8b2483e131922e8427223b52e688/certifi-2022.6.15.1-py3-none-any.whl (160kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading https://files.pythonhosted.org/packages/6f/de/5be2e3eed8426f871b170663333a0f627fc2924cc386cd41be065e7ea870/urllib3-1.26.12-py2.py3-none-any.whl (140kB)
# Collecting idna<4,>=2.5
#   Downloading https://files.pythonhosted.org/packages/04/a2/d918dcd22354d8958fe113e1a3630137e0fc8b44859ade3063982eacd2a4/idna-3.3-py3-none-any.whl (61kB)
# Collecting charset-normalizer<3,>=2
#   Downloading https://files.pythonhosted.org/packages/db/51/a507c856293ab05cdc1db77ff4bc1268ddd39f29e7dc4919aa497f0adbec/charset_normalizer-2.1.1-py3-none-any.whl
# Collecting importlib-metadata>=4.4; python_version < "3.10"
#   Downloading https://files.pythonhosted.org/packages/d2/a2/8c239dc898138f208dd14b441b196e7b3032b94d3137d9d8453e186967fc/importlib_metadata-4.12.0-py3-none-any.whl
# Collecting requests-oauthlib>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/6f/bb/5deac77a9af870143c684ab46a7934038a53eb4aa975bc0687ed6ca2c610/requests_oauthlib-1.3.1-py2.py3-none-any.whl
# Collecting pyasn1-modules>=0.2.1
#   Downloading https://files.pythonhosted.org/packages/95/de/214830a981892a3e286c3794f41ae67a4495df1108c3da8a9f62159b9a9d/pyasn1_modules-0.2.8-py2.py3-none-any.whl (155kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/68/aa/5fc646cae6e997c3adf3b0a7e257cda75cff21fcba15354dffd67789b7bb/cachetools-5.2.0-py3-none-any.whl
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Downloading https://files.pythonhosted.org/packages/49/97/fa78e3d2f65c02c8e1268b9aba606569fe97f6c8f7c2d74394553347c145/rsa-4.9-py3-none-any.whl
# Collecting MarkupSafe>=2.1.1
#   Downloading https://files.pythonhosted.org/packages/fd/f4/524d2e8f5a3727cf309c2b7df7c732038375322df1376c9e9ef3aa92fcaf/MarkupSafe-2.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Collecting zipp>=0.5
#   Downloading https://files.pythonhosted.org/packages/f0/36/639d6742bcc3ffdce8b85c31d79fcfae7bb04b95f0e5c4c6f8b206a038cc/zipp-3.8.1-py3-none-any.whl
# Collecting oauthlib>=3.0.0
#   Downloading https://files.pythonhosted.org/packages/92/bb/d669baf53d4ffe081dab80aad93c5c79f84eeac885dd31507c8c055a98d5/oauthlib-3.2.1-py3-none-any.whl (151kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading https://files.pythonhosted.org/packages/62/1e/a94a8d635fa3ce4cfc7f506003548d0a2447ae76fd5ca53932970fe3053f/pyasn1-0.4.8-py2.py3-none-any.whl (77kB)
# Installing collected packages: typing-extensions, six, google-pasta, numpy, h5py, flatbuffers, protobuf, tensorflow-io-gcs-filesystem, keras-preprocessing, absl-py, gast, opt-einsum, termcolor, pyparsing, packaging, wheel, astunparse, certifi, urllib3, idna, charset-normalizer, requests, zipp, importlib-metadata, markdown, pyasn1, pyasn1-modules, cachetools, rsa, google-auth, oauthlib, requests-oauthlib, google-auth-oauthlib, tensorboard-data-server, grpcio, tensorboard-plugin-wit, MarkupSafe, werkzeug, tensorboard, tensorflow-estimator, keras, wrapt, libclang, tensorflow
# Successfully installed MarkupSafe-2.1.1 absl-py-1.2.0 astunparse-1.6.3 cachetools-5.2.0 certifi-2022.6.15.1 charset-normalizer-2.1.1 flatbuffers-2.0.7 gast-0.4.0 google-auth-2.11.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.48.1 h5py-3.7.0 idna-3.3 importlib-metadata-4.12.0 keras-2.10.0 keras-preprocessing-1.1.2 libclang-14.0.6 markdown-3.4.1 numpy-1.23.3 oauthlib-3.2.1 opt-einsum-3.3.0 packaging-21.3 protobuf-3.19.4 pyasn1-0.4.8 pyasn1-modules-0.2.8 pyparsing-3.0.9 requests-2.28.1 requests-oauthlib-1.3.1 rsa-4.9 six-1.16.0 tensorboard-2.10.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.10.0 tensorflow-estimator-2.10.0 tensorflow-io-gcs-filesystem-0.27.0 termcolor-2.0.0 typing-extensions-4.3.0 urllib3-1.26.12 werkzeug-2.2.2 wheel-0.37.1 wrapt-1.14.1 zipp-3.8.1
# WARNING: You are using pip version 19.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# --> 7e95a3d75bf
# STEP 5/14: RUN pip install seldon-core
# Collecting seldon-core
#   Downloading https://files.pythonhosted.org/packages/28/cc/9d1b5a75bceb8ed37e1c96b5b3c6f5bcd08ab15fdb66fc6c587ea29c3710/seldon_core-1.14.1-py3-none-any.whl (115kB)
# Requirement already satisfied: grpcio<2.0.0 in /opt/app-root/lib/python3.8/site-packages (from seldon-core) (1.48.1)
# Collecting jaeger-client<4.5.0,>=4.1.0
#   Downloading https://files.pythonhosted.org/packages/cb/45/aa60d2fe5e727e718c2cd2e9fa5b240f59c2c12cb9213b1c8709e4e115eb/jaeger-client-4.4.0.tar.gz (83kB)
# Collecting markupsafe==1.1.1
#   Downloading https://files.pythonhosted.org/packages/80/16/98afa5c19296aaf7b16d1eb3c7e997656e6cfad79606e7d3885905615e96/MarkupSafe-1.1.1-cp38-cp38-manylinux2010_x86_64.whl
# Collecting itsdangerous==1.1.0
#   Downloading https://files.pythonhosted.org/packages/76/ae/44b03b253d6fade317f32c24d100b3b35c2239807046a4c953c7b89fa49e/itsdangerous-1.1.0-py2.py3-none-any.whl
# Collecting opentracing<2.5.0,>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/51/28/2dba4e3efb64cc59d4311081a5ddad1dde20a19b69cd0f677cdb2f2c29a6/opentracing-2.4.0.tar.gz (46kB)
# Collecting Flask<2.0.0
#   Downloading https://files.pythonhosted.org/packages/e8/6d/994208daa354f68fd89a34a8bafbeaab26fda84e7af1e35bdaed02b667e6/Flask-1.1.4-py2.py3-none-any.whl (94kB)
# Requirement already satisfied: requests<3.0.0 in /opt/app-root/lib/python3.8/site-packages (from seldon-core) (2.28.1)
# Collecting click<8.1,>=8.0.0a1
#   Downloading https://files.pythonhosted.org/packages/4a/a8/0b2ced25639fb20cc1c9784de90a8c25f9504a7f18cd8b5397bd61696d7d/click-8.0.4-py3-none-any.whl (97kB)
# Collecting urllib3==1.26.5
#   Downloading https://files.pythonhosted.org/packages/0c/cd/1e2ec680ec7b09846dc6e605f5a7709dfb9d7128e51a026e7154e18a234e/urllib3-1.26.5-py2.py3-none-any.whl (138kB)
# Collecting grpcio-reflection<1.35.0
#   Downloading https://files.pythonhosted.org/packages/16/4c/7b05077d9a3d7e60df742ab507578c501cc05861f4328ba4919fc799d72b/grpcio-reflection-1.34.1.tar.gz
# Requirement already satisfied: numpy<2.0.0 in /opt/app-root/lib/python3.8/site-packages (from seldon-core) (1.23.3)
# Collecting Flask-cors<4.0.0
#   Downloading https://files.pythonhosted.org/packages/db/84/901e700de86604b1c4ef4b57110d4e947c218b9997adf5d38fa7da493bce/Flask_Cors-3.0.10-py2.py3-none-any.whl
# Requirement already satisfied: protobuf<4.0.0 in /opt/app-root/lib/python3.8/site-packages (from seldon-core) (3.19.4)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/app-root/lib/python3.8/site-packages (from seldon-core) (41.6.0)
# Collecting werkzeug<2.1
#   Downloading https://files.pythonhosted.org/packages/f4/f3/22afbdb20cc4654b10c98043414a14057cd27fdba9d4ae61cea596000ba2/Werkzeug-2.0.3-py3-none-any.whl (289kB)
# Collecting jsonschema<4.0.0
#   Downloading https://files.pythonhosted.org/packages/c5/8f/51e89ce52a085483359217bc72cdbf6e75ee595d5b1d4b5ade40c7e018b8/jsonschema-3.2.0-py2.py3-none-any.whl (56kB)
# Collecting gunicorn<20.2.0,>=19.9.0
#   Downloading https://files.pythonhosted.org/packages/e4/dd/5b190393e6066286773a67dfcc2f9492058e9b57c4867a95f1ba5caf0a83/gunicorn-20.1.0-py3-none-any.whl (79kB)
# Collecting grpcio-opentracing<1.2.0,>=1.1.4
#   Downloading https://files.pythonhosted.org/packages/db/82/2fcad380697c3dab25de76ee590bcab3eb9bbfb4add916044d7e83ec2b10/grpcio_opentracing-1.1.4-py3-none-any.whl
# Collecting prometheus-client<0.9.0,>=0.7.1
#   Downloading https://files.pythonhosted.org/packages/3f/0e/554a265ffdc56e1494ef08e18f765b0cdec78797f510c58c45cf37abb4f4/prometheus_client-0.8.0-py2.py3-none-any.whl (53kB)
# Collecting flatbuffers<2.0.0
#   Downloading https://files.pythonhosted.org/packages/eb/26/712e578c5f14e26ae3314c39a1bdc4eb2ec2f4ddc89b708cf8e0a0d20423/flatbuffers-1.12-py2.py3-none-any.whl
# Collecting PyYAML<5.5,>=5.4
#   Downloading https://files.pythonhosted.org/packages/70/96/c7245e551b1cb496bfb95840ace55ca60f20d3d8e33d70faf8c78a976899/PyYAML-5.4.1-cp38-cp38-manylinux1_x86_64.whl (662kB)
# Collecting cryptography<3.5,>=3.4
#   Downloading https://files.pythonhosted.org/packages/96/07/4d23f8e34e56d8eeb2c37cd5924928a01c3dd756a1d99e470181bc57551e/cryptography-3.4.8-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2MB)
# Collecting Flask-OpenTracing<1.2.0,>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/58/6c/6417701ba5ecc8854670c6db3207bcc3e5fbc96289a7cb18d5516d99a1c6/Flask-OpenTracing-1.1.0.tar.gz
# Requirement already satisfied: six>=1.5.2 in /opt/app-root/lib/python3.8/site-packages (from grpcio<2.0.0->seldon-core) (1.16.0)
# Collecting threadloop<2,>=1
#   Downloading https://files.pythonhosted.org/packages/d3/1d/8398c1645b97dc008d3c658e04beda01ede3d90943d40c8d56863cf891bd/threadloop-1.0.2.tar.gz
# Collecting thrift
#   Downloading https://files.pythonhosted.org/packages/e4/23/dd951c9883cb49a73b750bdfe91e39d78e8a3f1f7175608634f381a197d5/thrift-0.16.0.tar.gz (59kB)
# Collecting tornado>=4.3
#   Downloading https://files.pythonhosted.org/packages/19/bb/b6c3d1668d2b10ad38a584f3a1ec9737984e274f8b708e09fcbb96427f5c/tornado-6.2-cp37-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (423kB)
# Collecting Jinja2<3.0,>=2.10.1
#   Downloading https://files.pythonhosted.org/packages/7e/c2/1eece8c95ddbc9b1aeb64f5783a9e07a286de42191b7204d67b7496ddf35/Jinja2-2.11.3-py2.py3-none-any.whl (125kB)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.8/site-packages (from requests<3.0.0->seldon-core) (2022.6.15.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/app-root/lib/python3.8/site-packages (from requests<3.0.0->seldon-core) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.8/site-packages (from requests<3.0.0->seldon-core) (3.3)
# Collecting pyrsistent>=0.14.0
#   Downloading https://files.pythonhosted.org/packages/58/6e/d456cfc71009aef515206201474a115ec68ec20307e4909e60e182292e90/pyrsistent-0.18.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (119kB)
# Collecting attrs>=17.4.0
#   Downloading https://files.pythonhosted.org/packages/f2/bc/d817287d1aa01878af07c19505fafd1165cd6a119e9d0821ca1d1c20312d/attrs-22.1.0-py2.py3-none-any.whl (58kB)
# Collecting cffi>=1.12
#   Downloading https://files.pythonhosted.org/packages/b7/8b/06f30caa03b5b3ac006de4f93478dbd0239e2a16566d81a106c322dc4f79/cffi-1.15.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442kB)
# Collecting pycparser
#   Downloading https://files.pythonhosted.org/packages/62/d5/5f610ebe421e85889f2e55e33b7f9a6795bd982198517d912eb1c76e1a53/pycparser-2.21-py2.py3-none-any.whl (118kB)
# Building wheels for collected packages: jaeger-client, opentracing, grpcio-reflection, Flask-OpenTracing, threadloop, thrift
#   Building wheel for jaeger-client (setup.py): started
#   Building wheel for jaeger-client (setup.py): finished with status 'done'
#   Created wheel for jaeger-client: filename=jaeger_client-4.4.0-cp38-none-any.whl size=64326 sha256=b27973621ab88c911a24b615a96927065fcc64551a3205edc5de2a545d0d7f41
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nfiqkcqd/wheels/fa/d4/ec/1ad2c2de6b5cdd43a6557226e398c8c0ee8615569a3f9b291a
#   Building wheel for opentracing (setup.py): started
#   Building wheel for opentracing (setup.py): finished with status 'done'
#   Created wheel for opentracing: filename=opentracing-2.4.0-cp38-none-any.whl size=51401 sha256=da3ba43f06b84be8d36b8773be5bbbf425a9e912e679422c103d7eb25ffe9c17
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nfiqkcqd/wheels/27/b6/a0/d0309988a0dd5623c34469b151e4d7b0e6271b28a8bcccb440
#   Building wheel for grpcio-reflection (setup.py): started
#   Building wheel for grpcio-reflection (setup.py): finished with status 'done'
#   Created wheel for grpcio-reflection: filename=grpcio_reflection-1.34.1-cp38-none-any.whl size=14413 sha256=65010a3163496a261e9cd039751027c255f739e77b527aaff7dd59f23a6d7c2d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nfiqkcqd/wheels/85/0e/79/919373e994613ef41ec9ffcd6ee9dd7952ab0dc2bbf963d209
#   Building wheel for Flask-OpenTracing (setup.py): started
#   Building wheel for Flask-OpenTracing (setup.py): finished with status 'done'
#   Created wheel for Flask-OpenTracing: filename=Flask_OpenTracing-1.1.0-cp38-none-any.whl size=9072 sha256=0ded2611157c7e0c60f73403a6658419d5fd54fd8c2a1dc166992267b32c74ca
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nfiqkcqd/wheels/7b/dc/25/3cf0b35c129232ee596c413f13d1d1f5a8e38c427266276dfd
#   Building wheel for threadloop (setup.py): started
#   Building wheel for threadloop (setup.py): finished with status 'done'
#   Created wheel for threadloop: filename=threadloop-1.0.2-cp38-none-any.whl size=3426 sha256=04a439f8dca0a868fc45964dbe8613a91eb3a60797682bdc8208c0af853c99d4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nfiqkcqd/wheels/d7/7a/30/d212623a4cd34f6cce400f8122b1b7af740d3440c68023d51f
#   Building wheel for thrift (setup.py): started
#   Building wheel for thrift (setup.py): finished with status 'done'
#   Created wheel for thrift: filename=thrift-0.16.0-cp38-cp38-linux_x86_64.whl size=404106 sha256=34b0bf6b2b29f8e6b88fb65a39e04993dc963a4a1825044092745c78335ba595
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nfiqkcqd/wheels/70/67/9d/84bb587c0c1d15c5c225ca4572fea68a61b85c3c12918098bd
# Successfully built jaeger-client opentracing grpcio-reflection Flask-OpenTracing threadloop thrift
# ERROR: tensorflow 2.10.0 has requirement flatbuffers>=2.0, but you'll have flatbuffers 1.12 which is incompatible.
# ERROR: flask 1.1.4 has requirement click<8.0,>=5.1, but you'll have click 8.0.4 which is incompatible.
# ERROR: flask 1.1.4 has requirement Werkzeug<2.0,>=0.15, but you'll have werkzeug 2.0.3 which is incompatible.
# Installing collected packages: tornado, threadloop, thrift, opentracing, jaeger-client, markupsafe, itsdangerous, werkzeug, click, Jinja2, Flask, urllib3, grpcio-reflection, Flask-cors, pyrsistent, attrs, jsonschema, gunicorn, grpcio-opentracing, prometheus-client, flatbuffers, PyYAML, pycparser, cffi, cryptography, Flask-OpenTracing, seldon-core
#   Found existing installation: MarkupSafe 2.1.1
#     Uninstalling MarkupSafe-2.1.1:
#       Successfully uninstalled MarkupSafe-2.1.1
#   Found existing installation: Werkzeug 2.2.2
#     Uninstalling Werkzeug-2.2.2:
#       Successfully uninstalled Werkzeug-2.2.2
#   Found existing installation: urllib3 1.26.12
#     Uninstalling urllib3-1.26.12:
#       Successfully uninstalled urllib3-1.26.12
#   Found existing installation: flatbuffers 2.0.7
#     Uninstalling flatbuffers-2.0.7:
#       Successfully uninstalled flatbuffers-2.0.7
# Successfully installed Flask-1.1.4 Flask-OpenTracing-1.1.0 Flask-cors-3.0.10 Jinja2-2.11.3 PyYAML-5.4.1 attrs-22.1.0 cffi-1.15.1 click-8.0.4 cryptography-3.4.8 flatbuffers-1.12 grpcio-opentracing-1.1.4 grpcio-reflection-1.34.1 gunicorn-20.1.0 itsdangerous-1.1.0 jaeger-client-4.4.0 jsonschema-3.2.0 markupsafe-1.1.1 opentracing-2.4.0 prometheus-client-0.8.0 pycparser-2.21 pyrsistent-0.18.1 seldon-core-1.14.1 threadloop-1.0.2 thrift-0.16.0 tornado-6.2 urllib3-1.26.5 werkzeug-2.0.3
# WARNING: You are using pip version 19.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# --> 01aece96de8
# STEP 6/14: RUN pip install joblib
# Collecting joblib
#   Downloading https://files.pythonhosted.org/packages/3e/d5/0163eb0cfa0b673aa4fe1cd3ea9d8a81ea0f32e50807b0c295871e4aab2e/joblib-1.1.0-py2.py3-none-any.whl (306kB)
# Installing collected packages: joblib
# Successfully installed joblib-1.1.0
# WARNING: You are using pip version 19.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# --> 0a48535b5aa
# STEP 7/14: RUN pip install scikit-learn
# Collecting scikit-learn
#   Downloading https://files.pythonhosted.org/packages/91/d1/50eb92222e8b2f315ec5499b97a926d271305e19e254fdced4db899647d6/scikit_learn-1.1.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31.2MB)
# Collecting scipy>=1.3.2
#   Downloading https://files.pythonhosted.org/packages/6f/7c/aa0abf51b2f68b97135e5a25938c4040a718a181b8d4602d0e2df3915e5a/scipy-1.9.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.4MB)
# Requirement already satisfied: numpy>=1.17.3 in /opt/app-root/lib/python3.8/site-packages (from scikit-learn) (1.23.3)
# Requirement already satisfied: joblib>=1.0.0 in /opt/app-root/lib/python3.8/site-packages (from scikit-learn) (1.1.0)
# Collecting threadpoolctl>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/61/cf/6e354304bcb9c6413c4e02a747b600061c21d38ba51e7e544ac7bc66aecc/threadpoolctl-3.1.0-py3-none-any.whl
# Installing collected packages: scipy, threadpoolctl, scikit-learn
# Successfully installed scikit-learn-1.1.2 scipy-1.9.1 threadpoolctl-3.1.0
# WARNING: You are using pip version 19.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# --> 8e0031389c0
# STEP 8/14: RUN pip install tensorflow
# Requirement already satisfied: tensorflow in /opt/app-root/lib/python3.8/site-packages (2.10.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/app-root/lib/python3.8/site-packages (from tensorflow) (3.3.0)
# Collecting flatbuffers>=2.0
#   Downloading https://files.pythonhosted.org/packages/d7/0d/b5bfb553a6ac66d6ec2b6d7f1e814a908fba7188356ac94bb36ae3d905c3/flatbuffers-2.0.7-py2.py3-none-any.whl
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/app-root/lib/python3.8/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: setuptools in /opt/app-root/lib/python3.8/site-packages (from tensorflow) (41.6.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/app-root/lib/python3.8/site-packages (from tensorflow) (4.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow) (1.2.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in /opt/app-root/lib/python3.8/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /opt/app-root/lib/python3.8/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/app-root/lib/python3.8/site-packages (from tensorflow) (0.27.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /opt/app-root/lib/python3.8/site-packages (from tensorflow) (3.19.4)
# Requirement already satisfied: libclang>=13.0.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: h5py>=2.9.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/app-root/lib/python3.8/site-packages (from tensorflow) (1.48.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: six>=1.12.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: numpy>=1.20 in /opt/app-root/lib/python3.8/site-packages (from tensorflow) (1.23.3)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: packaging in /opt/app-root/lib/python3.8/site-packages (from tensorflow) (21.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /opt/app-root/lib/python3.8/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: keras<2.11,>=2.10.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/app-root/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /opt/app-root/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/app-root/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /opt/app-root/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/app-root/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.0.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/app-root/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.11.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/app-root/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in /opt/app-root/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.37.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/app-root/lib/python3.8/site-packages (from packaging->tensorflow) (3.0.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/app-root/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in /opt/app-root/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (4.12.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2022.6.15.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/app-root/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.5)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/app-root/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.1.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /opt/app-root/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/app-root/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (5.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/app-root/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.1)
# Requirement already satisfied: zipp>=0.5 in /opt/app-root/lib/python3.8/site-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (3.8.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/app-root/lib/python3.8/site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# ERROR: seldon-core 1.14.1 has requirement flatbuffers<2.0.0, but you'll have flatbuffers 2.0.7 which is incompatible.
# Installing collected packages: flatbuffers
#   Found existing installation: flatbuffers 1.12
#     Uninstalling flatbuffers-1.12:
#       Successfully uninstalled flatbuffers-1.12
# Successfully installed flatbuffers-2.0.7
# WARNING: You are using pip version 19.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# --> 432925c16e1
# STEP 9/14: RUN pip install pandas
# Collecting pandas
#   Downloading https://files.pythonhosted.org/packages/91/b6/d8b292b084233b2fe46eb514af6b48238530e85b97d2b28a25d12faac1bc/pandas-1.4.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7MB)
# Collecting python-dateutil>=2.8.1
#   Downloading https://files.pythonhosted.org/packages/36/7a/87837f39d0296e723bb9b62bbb257d0355c7f6128853c78955f57342a56d/python_dateutil-2.8.2-py2.py3-none-any.whl (247kB)
# Collecting pytz>=2020.1
#   Downloading https://files.pythonhosted.org/packages/d5/50/54451e88e3da4616286029a3a17fc377de817f66a0f50e1faaee90161724/pytz-2022.2.1-py2.py3-none-any.whl (500kB)
# Requirement already satisfied: numpy>=1.18.5; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in /opt/app-root/lib/python3.8/site-packages (from pandas) (1.23.3)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: python-dateutil, pytz, pandas
# Successfully installed pandas-1.4.4 python-dateutil-2.8.2 pytz-2022.2.1
# WARNING: You are using pip version 19.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# --> 04b7ff6823f
# STEP 10/14: COPY Predictor.py model.h5 /microservice/
# --> 274455efc78
# STEP 11/14: ENV PERSISTENCE 0
# --> b57e0120e35
# STEP 12/14: CMD seldon-core-microservice $MODEL_NAME --service-type $SERVICE_TYPE --persistence $PERSISTENCE --grpc-port ${GRPC_PORT} --metrics-port ${METRICS_PORT} --http-port ${HTTP_PORT}
# --> 2a41eb30e88
# STEP 13/14: ENV "OPENSHIFT_BUILD_NAME"="seldon-model-pred-demo-opentlc-mgr-v1-1" "OPENSHIFT_BUILD_NAMESPACE"="ml-workshop"
# --> 4120a48f05b
# STEP 14/14: LABEL "io.openshift.build.name"="seldon-model-pred-demo-opentlc-mgr-v1-1" "io.openshift.build.namespace"="ml-workshop"
# COMMIT temp.builder.openshift.io/ml-workshop/seldon-model-pred-demo-opentlc-mgr-v1-1:4f76eb48
# --> 9022642bfbc
# Successfully tagged temp.builder.openshift.io/ml-workshop/seldon-model-pred-demo-opentlc-mgr-v1-1:4f76eb48
# 9022642bfbcfa053134ab1241eccabdf3870249be1f0276f3a00239932fa97dd
#
# Pushing image image-registry.openshift-image-registry.svc:5000/ml-workshop/seldon-model-pred-demo-opentlc-mgr-v1:latest ...
# Getting image source signatures
# Copying blob sha256:90e4dbbb7e3135537e5293a2491c02df6646a1329ed3333ff465bfc5bad2df5c
# Copying blob sha256:06038631a24a25348b51d1bfc7d0a0ee555552a8998f8328f9b657d02dd4c64c
# Copying blob sha256:be84118e6017ca944a551a0f22d93ae3600941ea76e13cb01be584ab822cdecf
# Copying blob sha256:262268b65bd5f33784d6a61514964887bc18bc00c60c588bc62bfae7edca46f1
# Copying blob sha256:c101ad5bb4fe96ea9b773498ec3f14371a0da1110add338f003c8c9cdbf15d07
# Copying blob sha256:44115d860fcecaa250b811cc4120d7ba18a2250bada1fe15199de53cefde7fc7
# Copying blob sha256:f489d50f906800c98b92e215d5e0e7b81e453ea60930aa6788faff10b9dada52
# Copying blob sha256:be80142a70e9835662304d3d9c32dec798666984235842f68e724595c24a03b9
# Copying blob sha256:85acdbbd7d78e3d51169cb8833239d84464c162d289127930c87e1c4e87ec3e2
# Copying blob sha256:eaf6565e8b62050f04ec4632ee596f08f67b22f32bb6ac931141cfd76973af15
# Copying blob sha256:b303407a46dbb3c9da8aaddaebe83610cdbe450ea9717825e161df61beb69d08
# Copying blob sha256:1987b1314748c69df0e2a377ab2ccd1d53723b93c9d908a5d73523ac2ca27fda
# Copying blob sha256:b7df27c9ec0d959dab43006a530c771b291b6428f51b91d2142c7578ea84d31d
# Copying config sha256:9022642bfbcfa053134ab1241eccabdf3870249be1f0276f3a00239932fa97dd
# Writing manifest to image destination
# Storing signatures
# Successfully pushed image-registry.openshift-image-registry.svc:5000/ml-workshop/seldon-model-pred-demo-opentlc-mgr-v1@sha256:6fcfc06c0d8b8a2791f976666fd32a6ca6886fb535bcfb113946175b1826da98
# Push successful
#
#
# apiVersion: machinelearning.seldon.io/v1
# kind: SeldonDeployment
# metadata:
#   labels:
#     app: seldon
#   name: model-1
# spec:
#   annotations:
#     project_name: pred-demo-opentlc-mgr
#     deployment_version: "1"
#   #     seldon.io/engine-separate-pod: "true"
#   name: pred-demo-opentlc-mgr-spec
#   predictors:
#     - componentSpecs:
#         - hpaSpec:
#             maxReplicas: 5
#             metrics:
#               - resource:
#                   name: cpu
#                   targetAverageUtilization: 80
#                 type: Resource
#             minReplicas: 1
#           spec:
#             containers:
#
#               - image: "image-registry.openshift-image-registry.svc:5000/ml-workshop/seldon-model-pred-demo-opentlc-mgr-v1"
#                 imagePullPolicy: Always
#                 name: pred-demo-opentlc-mgrpredictor
#                 env:
#                   - name: MODEL_NAME
#                     value: "Predictor"
#                   - name: SERVICE_TYPE
#                     value: MODEL
#                   - name: GRPC_PORT
#                     value: "5007"
#                   - name: METRICS_PORT
#                     value: "6007"
#                   - name: HTTP_PORT
#                     value: "9000"
#
#
#       graph:
#
#
#         name: pred-demo-opentlc-mgrpredictor
#         type: MODEL
#         endpoint:
#           type: REST
#           service_host: localhost
#           service_port: 9000
#         # logger:
#         #   url: http://logger.seldon/
#         #   mode: all
#
#       name: predictor
#       annotations:
#         predictor_version: "1"
#         team: opendatahub
#         seldon.io/svc-name: model-1-pred-demo-opentlc-mgr
#       labels:
#         team: opendatahub
#         version: predictor
#
#       replicas: 1
# 0
# model-1-pred-demo-opentlc-mgr

# %% [markdown]
# # 4. **Test the Predictive Maintenance app**

# %% [markdown]
# ## 4.1. Get the app route

# %%
# This cell reads the name of the route from a file that was created in the previous cell's call. 
with open('routeHost.txt') as f:
    lines = f.readlines()
    
routeHost=lines[0]

path='/api/v1.0/predictions'

my_route = 'http://'+routeHost+path

print ("Inference URL:")
print (my_route)
# Out:
# Inference URL:
# http://model-1-pred-demo-opentlc-mgr-ml-workshop.apps.rosa-wztqh.8u8m.p1.openshiftapps.com/api/v1.0/predictions

# %% [markdown]
# ## 4.2. Read the test data

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
im = Image.open("/opt/app-root/src/predictive-maint/training/notebooks/sample.jpg")
img = np.asarray(im)
plt.imshow(img)
plt.show()

# %% [markdown]
# ## 4.3. Make a decision based on input data

# %%
import base64
import requests
from json import dumps
my_image = '/opt/app-root/src/predictive-maint/training/notebooks/sample.jpg'
with open(my_image, "rb") as image_file:
    encoded_image = base64.b64encode(image_file.read()).decode('utf-8')

content = {"data":
          {
                "names":
                    ["Sentence"],
             "ndarray": img.tolist()

          }
        }
json_data = dumps(content)
headers = {"Content-Type" : "application/json"}





r = requests.post(my_route , data=json_data, headers=headers)
r.json()
# Out:
# '{"Predicted Class: ": "Background", "Predicted Label: ": "[0]", "Predicted Class Prob: ": "\\"[0.6193621]\\"", "All Probs: ": "[[0.6193621158599854, 0.23706412315368652, 0.1435738056898117]]"}'

# %%
import os
import tensorflow as tf

import joblib
import numpy as np
import json
import traceback
import sys


class Predictor(object):
    
    def __init__(self):
        self.loaded = False
        self.labels = ["Background","Finger","Person"]

    def load(self):

        print("Loading model",os.getpid())
        self.model = tf.keras.models.load_model( '/opt/app-root/src/predictive-maint/training/deploy/model.h5', compile=False)
        print("Model Loaded!")
        self.loaded = True
        print("Loaded model")

    def predict_raw(self, data):
        print('step 00')
        if data:
            float_array = tf.constant(np.array(data))
            float_array = tf.expand_dims(float_array, 0)
            print('step 01')

        print ('step1......')
        print(float_array.shape)

      
        if not self.loaded:
            self.load()
        try:
            result = self.model.predict(float_array) 
        except Exception as e:
            print(traceback.format_exception(*sys.exc_info()))
        
        ######


        
        json_results = {}
        arg_max_result = tf.math.argmax(result,axis=1)
        print("1"*50)
        print(arg_max_result)
        json_results["Predicted Class: "] = str(self.labels[int(arg_max_result)])
        print("2"*50)
        
        json_results["Predicted Label: "] = json.dumps(arg_max_result.numpy(), cls=JsonSerializer)
        print("3"*50)
        json_results["Predicted Class Prob: "] = json.dumps(str(np.max(result, axis=1)), cls=JsonSerializer)
        print("4"*50)
        json_results["All Probs: "] = json.dumps(result, cls=JsonSerializer)
        
        
        print(json_results)
        print (result)
        print(json.dumps(json_results))
        return json.dumps(json_results)
        # return json.dumps(result.numpy(), cls=JsonSerializer)

class JsonSerializer(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, (
        np.int_, np.intc, np.intp, np.int8, np.int16, np.int32, np.int64, np.uint8, np.uint16, np.uint32, np.uint64)):
            return int(obj)
        elif isinstance(obj, (np.float_, np.float16, np.float32, np.float64)):
            return float(obj)
        elif isinstance(obj, (np.ndarray,)):
            return obj.tolist()
        return json.JSONEncoder.default(self, obj)

# %%
Predictor().predict_raw(img.tolist())
# Out:
# step 00
# step 01
# step1......
# (1, 256, 256, 3)
# Loading model 1470
# Model Loaded!
# Loaded model
# 1/1 [==============================] - 1s 1s/step
# 11111111111111111111111111111111111111111111111111
# tf.Tensor([0], shape=(1,), dtype=int64)
# 22222222222222222222222222222222222222222222222222
# 33333333333333333333333333333333333333333333333333
# 44444444444444444444444444444444444444444444444444
# {'Predicted Class: ': 'Background', 'Predicted Label: ': '[0]', 'Predicted Class Prob: ': '"[0.6193621]"', 'All Probs: ': '[[0.6193621158599854, 0.23706412315368652, 0.1435738056898117]]'}
# [[0.6193621  0.23706412 0.1435738 ]]
# {"Predicted Class: ": "Background", "Predicted Label: ": "[0]", "Predicted Class Prob: ": "\"[0.6193621]\"", "All Probs: ": "[[0.6193621158599854, 0.23706412315368652, 0.1435738056898117]]"}
# '{"Predicted Class: ": "Background", "Predicted Label: ": "[0]", "Predicted Class Prob: ": "\\"[0.6193621]\\"", "All Probs: ": "[[0.6193621158599854, 0.23706412315368652, 0.1435738056898117]]"}'

# %% [markdown]
# __Thank you for your time!__
